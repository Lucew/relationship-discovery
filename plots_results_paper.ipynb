# %%
import rankSPI as rspi
import logging
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# %%
# get figure 7a from the paper (ranking plots of all SPIs for all datasets)
_, _, overall_rank, complete_ranks = rspi.make_create_ranks(metric_subset="all", dataset_subset="all", use_fused=False)
fig1 = rspi.make_parallel_group_plot(complete_ranks, overall_rank)

# %%
# get figure 7b from the paper (ranking plots of all SPIs for all datasets)
_, _, overall_rank, complete_ranks = rspi.make_create_ranks(metric_subset="all", dataset_subset="plant", use_fused=False)
fig1 = rspi.make_parallel_group_plot(complete_ranks, overall_rank)

# %%
# get figure 7c from the paper (ranking plots of all SPIs for all datasets)
_, _, overall_rank, complete_ranks = rspi.make_create_ranks(metric_subset="all", dataset_subset="building", use_fused=False)
fig1 = rspi.make_parallel_group_plot(complete_ranks, overall_rank)

# %%
# get figure 3a from the paper (ranks of the different SPIs)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="ir", dataset_subset="all", use_fused=False)
fig2 = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 3b from the paper (ranks of the different SPIs)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="cluster", dataset_subset="all", use_fused=False)
fig2 = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 4a from the paper (ranks of the different SPIs)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="ir", dataset_subset="plant", use_fused=False)
fig2 = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 4b from the paper (ranks of the different SPIs)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="cluster", dataset_subset="plant", use_fused=False)
fig2 = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 5a from the paper (ranks of the different SPIs)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="ir", dataset_subset="building", use_fused=False)
fig2 = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 5b from the paper (ranks of the different SPIs)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="cluster", dataset_subset="building", use_fused=False)
fig2 = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 6 from the paper (ranks of the different SPIs)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="all", dataset_subset="all", use_fused=True)
fig2 = rspi.make_vertical_group_plot(overall_rank)
