# %%
import rankSPI as rspi
import logging
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# %%
# get figure 7a from the paper (ranking plots of all SPIs for all datasets)
_, _, overall_rank, complete_ranks = rspi.make_create_ranks(metric_subset="all", dataset_subset="all", use_fused=False)
fig = rspi.make_parallel_group_plot(complete_ranks, overall_rank)

# %%
# get figure 7b from the paper (ranking plots of all SPIs for the plant datasets)
_, _, overall_rank, complete_ranks = rspi.make_create_ranks(metric_subset="all", dataset_subset="plant", use_fused=False)
fig = rspi.make_parallel_group_plot(complete_ranks, overall_rank)

# %%
# get figure 7c from the paper (ranking plots of all SPIs for the building datasets)
_, _, overall_rank, complete_ranks = rspi.make_create_ranks(metric_subset="all", dataset_subset="building", use_fused=False)
fig = rspi.make_parallel_group_plot(complete_ranks, overall_rank)

# %%
# get figure 3a from the paper (ranks of the different relationship measures using only the information retrieval metrics on all datasets)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="ir", dataset_subset="all", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 3b from the paper (ranks of the different relationship measures using only the clustering metrics on all datasets)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="cluster", dataset_subset="all", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 4a from the paper (ranks of the different relationship measures using only the information retrieval metrics on the plant datasets)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="ir", dataset_subset="plant", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 4b from the paper (ranks of the different relationship measures using only the clustering metrics on the plant datasets)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="cluster", dataset_subset="plant", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 5a from the paper (ranks of the different relationship measures using only the information retrieval metrics on the building datasets)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="ir", dataset_subset="building", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 5b from the paper (ranks of the different relationship measures using only the clustering metrics on the building datasets)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="cluster", dataset_subset="building", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)

# %%
# get figure 6 from the paper (ranks of the different relationship measures, including fused ones, using all metrics and all datasets)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="all", dataset_subset="all", use_fused=True)
fig = rspi.make_vertical_group_plot(overall_rank)

# %%
# additional information as coded in the images at the top (figure 7a as ranking plot)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="all", dataset_subset="all", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)

# %%
# additional information as coded in the images at the top (figure 7b as ranking plot)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="all", dataset_subset="plant", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)
# Shows how exceptionally well the power envelope correlation performs on the building datasets

# %%
# additional information as coded in the images at the top (figure 7c as ranking plot)
_, _, overall_rank, _ = rspi.make_create_ranks(metric_subset="all", dataset_subset="building", use_fused=False)
fig = rspi.make_vertical_group_plot(overall_rank)
# Shows how exceptionally well the precision matrix performs on the building datasets
